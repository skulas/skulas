# %% [markdown]
# # KRE Formula Experiments
#
# Try ideas of possible KRE formulas and test them.
#
# *Note*:<br>
# It'd be a good practice to write long code parts in the IDE and bring it here.

# %%
# All required inputs here
import pandas as pd
import matplotlib.pyplot as plt

# Global configurations
# %matplotlib
# %matplotlib nbagg
# %matplotlib notebook
plt.ion()

# %% [markdown]
# ## KRE economic engines to incentivize

# %% [markdown]
# ### Growth
#
# Basic growth formula
# \begin{equation*}
# AS_n\frac{\delta(AS_n)}{t}
# \end{equation*}
#
# $AS_n$: number of active spenders
#
# If the number of active spenderd does not grow over time, $AS_n$ does not grow, $\frac{\delta(AS_n)}{t}$ will become smaller by time, reducing the incentive part based on growth

# %% [markdown]
# ### Retention
# Retention is just about keeping the number active spenders.
# \begin{equation*}
# \Delta(AS_n)
# \end{equation*}
#
# This should be non-negative for any time lapse $\Delta(t)$

# %% [markdown]
# ### P2P and Earn
# Number of transactions grows ~2x number of wallets growth (meaning users trade with each other more than with the developer)<br>
# Reward developer that users earn KIN<br>
# Repeated wallet pairs are not rewarded twice or are rewarded less each transaction

# %% [markdown]
# ### Education
# Rewards based on activities that encourage users learning<br>
# Rewards are vested later, only if growth is detected afterwards

# %% [markdown]
# ### PoW
# Proof of Work
#
# KRE prizes shall become harder to win.<br>
# Hardening the prices _mining_ should depend on
# - Time
# - Number of Wallets
# - Similar transactions
#  - Similar wallet groups
#  - Time lapses between transactions, spends vs earns, circular spends
#  - Spend ammounts, higher variety on spend timing and ammout as business grows
#  - Other patterns ...
#
# PoW methods
# - Attach phone numbers to new wallets
# - p2p transactions graph should grow (exponentially?) with growth $\Delta(AS_n)>0$
# - Enter some human intervention every N transactions. Where N transactions bring significant KRE value.

# %% [markdown]
# # KRE budget size

# %% [markdown]
# ## Parameters
# - Target inflation rate
# - Number of active wallets vs number of providers (developers)
# - Vesting rate

# %% [markdown]
# ## Competition
# ### Fair split
# The budget shall not be direcly dependent on the number of developers or developer business size.
# ### KRE cap known upfront
# Same sum split according to merits.

# %% [markdown]
# ### Inflation Rate
# Different options to calculate the inflation rates
#
# KIN split in trillon of KIN (1 million million, $10^{12}$)
#
# - 3: held by Kik.com - not circulating
# - 6: held by the Kin foundation.
# - 1: liquid, available in the market. Circulating. It's 0.756097560976 KIN, actually. According to [this table](https://coinmarketcap.com/currencies/kin/historical-data/)
#
# From the $6x10^{12}KIN^{*}$ held by the foundation, there's a %20 (max) yearly budget to be spent.<br>
# The budget is split:
# - %15 injected into the market and used by the Kin org for operational expenses
# - %85 injected into the market throug the KRE
#
# *
# 6 Trillion = 6 million millions = $6x10^{12}$

# %%
# Whales - Big KIN Holders
# Kik holds 3e12 KIN (3 trillion, 3 million million)
# Kin foundation holds 6e12
# Circulating in the market 1e12
KIN_EXPONENT = 1e12

KIK_HOLDINGS = 3
KIN_HOLDINGS = 6
KIN_OUT = 1 # 0.756097560976 actually

# Yearly yearly budget to be released from Kin org holdings
LIQ_RATE = 0.2
# Part of the yearly budget to be used by Kin org opeartions
OPERATIONAL_LIQ = 0.15
# Part of the yearly budget to be used by the KRE
KRE_LIQ = 0.85

FIRST_YEAR = 2019
DECADE = list(range(0,9))

# Kin holdings release options
MAX_KIN_INTO_MAKRET=[0]*(len(DECADE))

# %% [markdown]
# #### Budget pushed into market.<br>
# Different scenarios
# - No KRE nor operations budget are spent (2018), lowest glass floor (zero spending)
# - The operations funds are used but no KRE funds are given, highest glass floor
# - The operations funds are used and KRE is used too. Glass ceiling.<br>
# This is the maximum liquidation rate of Kin org funds
# - Half of the operations and half of the KRE used.

# %%
def CalculateYearlyBudget(years, first_year, rate, initial_capital):
    remaining_funds = initial_capital
    annual_budget=[0]*(len(years))
    for year in years:
        yearly_funds = rate*remaining_funds
    #     yearly_funds = pow(LIQ_RATE,(year+1))*remaining_funds
        remaining_funds -= yearly_funds
        print(year + first_year)
        print('YF: {:0.2f}, RF: {:0.2f}'.format(yearly_funds, remaining_funds))
        annual_budget[year] = yearly_funds
    return annual_budget

print('MAX budget into market')
MAX_KIN_INTO_MAKRET = CalculateYearlyBudget(DECADE, FIRST_YEAR, LIQ_RATE, KIN_HOLDINGS)
print('-'*60)
print('1/2 budget into market')
HALF_KIN_INTO_MAKRET = CalculateYearlyBudget(DECADE, FIRST_YEAR, LIQ_RATE*0.5, KIN_HOLDINGS)
print('-'*60)
print('1/2 KRE into market')
HALF_KRE_INTO_MAKRET = CalculateYearlyBudget(DECADE, FIRST_YEAR, LIQ_RATE*KRE_LIQ*0.5, KIN_HOLDINGS)
print('-'*60)
print('Full operations budget into market')
OP_KIN_INTO_MAKRET = CalculateYearlyBudget(DECADE, FIRST_YEAR, LIQ_RATE*OPERATIONAL_LIQ, KIN_HOLDINGS)

# %% [markdown]
# #### Visualization of funds pushed into the market over the years

# %%
years = [x.__add__(FIRST_YEAR) for x in DECADE]
# plt.plot(years, MAX_KIN_INTO_MAKRET, years, OP_KIN_INTO_MAKRET, label=['KRE + Op', 'Op'])
fig = plt.figure('KIN Funds Liquidation', figsize=(8,6))
plt.plot(years, MAX_KIN_INTO_MAKRET, 
         years, OP_KIN_INTO_MAKRET, 
         years, HALF_KIN_INTO_MAKRET,
         years, HALF_KRE_INTO_MAKRET)
# plt.plot(years, MAX_KIN_INTO_MAKRET, label='KRE + Op')
# plt.plot(years, OP_KIN_INTO_MAKRET, label='Op')
plt.title('KIN Funds Liquidation')
plt.xlabel('Year')
plt.ylabel('Trillions of KIN')
plt.legend(['KRE + Op', 'Op', '1/2 Rate', '1/2 KRE'])

# %% [markdown]
# #### Inflation Rates
# Inflation rates calculated as the newly added KIN related to the existing KIN in circulation.<br>
# Circulating KIN can also be one of many parameters
# - 1 Tril KIN
# - 1 + 3 = 4 Tril KIN. Assuming Kik liquids all its funds by 2019
# - There are also alternatives so Kik partially executes KIN funds over the years
#
# **High Inflation Rate**<br>
# There's only **1 Trillion KIN circulating** in the market. Kik keeps its funds.

# %%
def CalculateAnnualInflation(years, initial_kin, kin_liq_over_years):
    annual_inflation_rate=[0]*(len(years))
    total_kin_in_market = initial_kin
    for year in years:
        inflation_rate = kin_liq_over_years[year] / total_kin_in_market * 100.0
        total_kin_in_market += kin_liq_over_years[year]
        annual_inflation_rate[year] = inflation_rate
        print(inflation_rate)
    return annual_inflation_rate

print('Operational Inflation')
OPERATIONAL_INFLATION = CalculateAnnualInflation(DECADE, KIN_OUT, OP_KIN_INTO_MAKRET)
print('-'*30)
print('Max Inflation')
MAX_INFLATION = CalculateAnnualInflation(DECADE, KIN_OUT, MAX_KIN_INTO_MAKRET)
print('-'*30)
print('Half Execution Inflation')
HALF_INFLATION = CalculateAnnualInflation(DECADE, KIN_OUT, HALF_KIN_INTO_MAKRET)

# %%
years = [x.__add__(FIRST_YEAR) for x in DECADE]
# plt.plot(years, MAX_KIN_INTO_MAKRET, years, OP_KIN_INTO_MAKRET, label=['KRE + Op', 'Op'])
fig = plt.figure('HIGH Yearly Inflation Rate', figsize=(8,6))
plt.plot(years, OPERATIONAL_INFLATION, 
         years, MAX_INFLATION, 
         years, HALF_INFLATION)
# plt.plot(years, MAX_KIN_INTO_MAKRET, label='KRE + Op')
# plt.plot(years, OP_KIN_INTO_MAKRET, label='Op')
plt.title('HIGH Yearly Inflation Rate')
plt.xlabel('Year')
plt.ylabel('Percent [%]')
plt.legend(['Op', 'KRE + Op', '1/2 Rate'])

# %% [markdown]
# **Low Inflation Rate**<br>
# There are **4 Trillion KIN in circulation**, simulatig Kik liquidated all their holdings during 2018.<br>
# In general, the rate of KIN would probably be lower at the first years than the previous, high inflation rates.

# %%
liquid_kin = KIK_HOLDINGS + KIN_OUT
print('Operational Inflation')
OPERATIONAL_INFLATION = CalculateAnnualInflation(DECADE, liquid_kin, OP_KIN_INTO_MAKRET)
print('-'*30)
print('Max Inflation')
MAX_INFLATION = CalculateAnnualInflation(DECADE, liquid_kin, MAX_KIN_INTO_MAKRET)
print('-'*30)
print('Half Execution Inflation')
HALF_INFLATION = CalculateAnnualInflation(DECADE, liquid_kin, HALF_KIN_INTO_MAKRET)

# %%
years = [x.__add__(FIRST_YEAR) for x in DECADE]
# plt.plot(years, MAX_KIN_INTO_MAKRET, years, OP_KIN_INTO_MAKRET, label=['KRE + Op', 'Op'])
fig = plt.figure('Low Yearly Inflation Rate', figsize=(8,6))
plt.plot(years, OPERATIONAL_INFLATION, 
         years, MAX_INFLATION, 
         years, HALF_INFLATION)
# plt.plot(years, MAX_KIN_INTO_MAKRET, label='KRE + Op')
# plt.plot(years, OP_KIN_INTO_MAKRET, label='Op')
plt.title('Low Yearly Inflation Rate')
plt.xlabel('Year')
plt.ylabel('Percent [%]')
plt.legend(['Op', 'KRE + Op', '1/2 Rate'])

# %% [markdown]
# # Economic Support through KRE

# %% [markdown]
# In this chapter we want to explore what is the substantial economic support kin can provide to companies through the KRE funds.<br>
# There a few **dependent** degrees of freedom
# - Anual support budget for each company
# - KIN - USD rate
# - Number of companies
# - Total Budget

# %%
TRILLION = 1e12
number_of_companies = 50
kin_usd_rate = 0.000039
total_budget_in_kin = 0.1*TRILLION

annual_support_buddget_per_company = total_budget_in_kin / number_of_companies * kin_usd_rate

print('Annual budget for each company: {} usd'.format(annual_support_buddget_per_company))

# %% [markdown]
# ## Inflation simulator
# **dl**: number of inflation itterations<br>
# __d__: step increment (not the inflation rate)<br>
# **suma**: the circulating liquidity. The initial value has impact on inflation evolution

# %%
infl = plt.figure('Inflation', figsize=(8,6))
suma = 50
d = 5
dl = 60
infl = [0]*dl
for i in range(dl):
    suma += d
    infl[i] = 20*(d / suma)

plt.plot(infl)
thexts = plt.xticks([0, dl/4, dl/2, 3/4*dl, dl], [2010,2011,2012,2013,2014])
yslc = slice(1,dl,10)
# print(infl)
# theyts = plt.yticks(infl[yslc],[0.1, 0.4, 0.6, 0.8, 0.9])
newy = [y - 0.1 for y in infl[yslc]]
theyts = plt.yticks(infl[yslc],newy)
# theyts = plt.yticks([0.52, 0.8, 1.75],[0.37, 0.68, 2.2])

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # KRE calculations on Digital Services
#
# ---
# ---
# ---

# %%
import pandas as pd
import datetime as dt
import qgrid
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib nbagg
plt.ion()

# %% [markdown]
# **Constants**

# %%
HISTORY_DATA_PATH = '/Users/skulas/Dev/Kin/_GIT_REPOS_/KRE/Notebooks/Data'
EXPORT_DATA_PATH = '/Users/skulas/Dev/Kin/Export_Data'
EPOCH_START = dt.datetime(1970,1,1)
DAYS_IN_MONTH = 30

# %% [markdown]
# **Dev name Lookup**

# %%
service_lookup_df = pd.read_csv('{}/services_lookup_14Jan2019.csv'.format(HISTORY_DATA_PATH))
def get_service_name(service_id):
    return service_lookup_df.loc[service_lookup_df.digital_service_id == service_id].digital_service_name.iloc[0]

ignore_list = ['3skw','54s3','7spn','8k7q','a4jj','anon','fpn3','j732','ooxb']

# display(service_lookup_df)
print(get_service_name('gg38'))
print(get_service_name('l83h'))

# %% [markdown]
# ## Unique Daily Participants
# Read CSV files from DB containig Daily Active Spenders DA Eearners and DA Peer to Peer<br>
# Remove all irrelevant services using the _ignore_list_ defined
# <p>
# <font color=red size=14>IMPORTANT:</font><br>
#     Data is expected to be sorted by time <b>ASCending</b>
# </p>

# %%
uDAS = pd.read_csv('{}/uDAS_13JAN19.csv'.format(HISTORY_DATA_PATH), parse_dates=['date'])
uDAS.drop(uDAS.index[uDAS['digital_service_id'].isin(ignore_list)], inplace = True)

uDAE = pd.read_csv('{}/uDAE_13JAN19.csv'.format(HISTORY_DATA_PATH), parse_dates=['date'])
(n_rows, n_columns) = uDAE.shape
print('num of rows before: {}'.format(n_rows))
uDAE.drop(uDAE.index[uDAE['digital_service_id'].isin(ignore_list)], inplace = True)
(n_rows, n_columns) = uDAE.shape
print('num of rows after dropping ignored services: {}'.format(n_rows))

uDP2P = pd.read_csv('{}/uDP2P_13JAN19.csv'.format(HISTORY_DATA_PATH), parse_dates=['date'])
uDP2P.drop(uDP2P.index[uDP2P['digital_service_id'].isin(ignore_list)], inplace = True)

display(uDAS.head(2))
display(uDAS.tail(2))

service_ids = service_lookup_df.digital_service_id.tolist() # uDAE.digital_service_id.unique()
# The ignored services won't appear in the service_ids list, no need to look for them
# ignores = list(filter(lambda x: x in ignore_list, service_ids))
# display(ignores)
print('We have {} services:'.format(len(service_ids)))
display(service_ids)

# %% [markdown]
# ## Basic DAS, DAE and DP2P Drawings for a desired service

# %%
def get_service_data(df, service_id=''):
    if len(service_id) > 0:
        return df.loc[df['digital_service_id'] == service_id]
    return None


def extract_service(service_id):
    service_udas = get_service_data(uDAS, service_id)
    service_udae = get_service_data(uDAE, service_id)
    service_up2p = get_service_data(uDP2P, service_id)
    
    return (service_udas, service_udae, service_up2p)

def get_time_edges(udae, udas, up2p):
    mind1 = udas.date.head(1)
    mind2 = udae.date.head(1)
    mind3 = up2p.date.head(1)
    minDate = pd.concat([mind1,mind2,mind3]).min()

    maxd1 = udas.date.tail(1)
    maxd2 = udae.date.tail(1)
    maxd3 = up2p.date.tail(1)
    maxDate = pd.concat([maxd1,maxd2,maxd3]).max()
    
    return(minDate, maxDate)
    
def draw_basics_for_service(service_id):
    numberOfSteps = 5
    
    s_udas, s_udae, s_up2p = extract_service(service_id)
    (minDate, maxDate) = get_time_edges(s_udae, s_udas, s_up2p)

    if type(minDate) is not pd.Timestamp:
        return
    if type(maxDate) is not pd.Timestamp:
        return
    
    timeDiff = maxDate - minDate
    print(timeDiff)
    timeStep = timeDiff / numberOfSteps
    timeX = [t*timeStep + minDate for t in range(numberOfSteps + 1)]
    
    # Let's draw!
    plot_title = get_service_name(service_id)
    sfig = plt.figure(plot_title, figsize=(4,3))
    splt = plt.plot(s_udas.date, s_udas.number_of_udas,
    s_udae.date, s_udae.number_of_udae,
    s_up2p.date, s_up2p.number_of_udp2p)
#     sfig.format_xdata = mdates.DateFormatter('%d/%m/%Y')
    sfig.autofmt_xdate()
    pltleg = plt.legend(['udas', 'udae', 'udp2p'])
    plttit = plt.title(plot_title)
    thexs = plt.xticks(timeX)

# draw_basics_for_service('kik')

# %% [markdown]
# ### Graphs

# %%
# draw_basics_for_service('gg38')
# draw_basics_for_service('ghik')
# draw_basics_for_service('pgbv')
for service_id in service_ids:
    print(service_id)
    draw_basics_for_service(service_id)

# %% [markdown]
# ## Scores Table Calculations

# %%
service_id = 'kik'
date_now = dt.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
month_offset = dt.timedelta(days=DAYS_IN_MONTH) # pd.offsets.MonthOffset(1)
two_months_offset = dt.timedelta(days=2*DAYS_IN_MONTH)
month_ago = date_now - month_offset
two_months_ago = date_now - two_months_offset

def get_last_time_segment(service_id, time_start=month_ago):
    s_udas, s_udae, s_up2p = extract_service(service_id)

    # print(month_ago)
    mudas = s_udas.loc[time_start <= s_udas.date]
    mudae = s_udae.loc[time_start <= s_udae.date]
    mudp2p = s_up2p.loc[time_start <= s_up2p.date]

    return (mudas, mudae, mudp2p)

def get_any_time_segment(service_id, time_start=two_months_ago, time_end=month_ago):
    if time_start > time_end:
        return(None, None, None)
    
    s_udas, s_udae, s_up2p = extract_service(service_id)

    tudas = s_udas.loc[(time_start <= s_udas.date) & (s_udas.date <= time_end)]
    tudae = s_udae.loc[(time_start <= s_udae.date) & (s_udae.date <= time_end)]
    tudp2p = s_up2p.loc[(time_start <= s_up2p.date) & (s_up2p.date <= time_end)]

    return (tudas, tudae, tudp2p)


def get_service_timely_counters(service_id, time_start=month_ago, time_end=None):
    if time_end is None:
        (mudas, mudae, mudp2p) = get_last_time_segment(service_id, time_start=time_start)
    else:
        (mudas, mudae, mudp2p) = get_any_time_segment(service_id, time_start=time_start, time_end=time_end)
        
    number_of_udas = mudas.number_of_udas.sum()
    number_of_udae = mudae.number_of_udae.sum()
    number_of_udp2p = mudp2p.number_of_udp2p.sum()
    service_name = get_service_name(service_id)
    return dict(digital_service_id = service_id,
                    name = service_name.capitalize(),
                    number_of_dae = number_of_udae,
                    number_of_das = number_of_udas,
                    number_of_p2p = number_of_udp2p
               )

# %%
# print('{} > {} ? ==> {}'.format(month_ago, two_months_ago, (month_ago > two_months_ago)))
# res = get_any_time_segment('kik', time_start=two_months_ago, time_end=month_ago)
# display(res)

# %% [markdown]
# ### Last Month

# %%
counters_arr = []
for service_id in service_ids:
    res = get_service_timely_counters(service_id)
    counters_arr.append(res)

monthly_ranks_df = pd.DataFrame(counters_arr)

p2p_points = []
spend_over_earn = []
earn_over_spend = []
for ix, row in monthly_ranks_df.iterrows():
    if row.number_of_das > 0:
        earn_over_spend.append(row.number_of_dae / row.number_of_das)
    else:
        earn_over_spend.append(0)
    
    if row.number_of_dae > 0:
        p2p_points.append(row.number_of_p2p / row.number_of_dae)
        spend_over_earn.append(row.number_of_das / row.number_of_dae)
    else:
        p2p_points.append(0)
        spend_over_earn.append(0)

# Normalize p2p relative to self (to the service itself)
# total_p2p = sum(p2p_points)
# p2p_parts = [x / total_p2p for x in p2p_points]
total_absolute_p2p = sum(monthly_ranks_df['number_of_p2p'])
# Normalize p2p relative to the community
p2p_parts = monthly_ranks_df['number_of_p2p'] / total_absolute_p2p
monthly_ranks_df['p2p_score'] = p2p_points
monthly_ranks_df['p2p_part'] = p2p_parts

# Normalize spend over earn
total_soe = sum(spend_over_earn)
soe_parts = [x / total_soe for x in spend_over_earn]
monthly_ranks_df['s_o_e_score'] = spend_over_earn
monthly_ranks_df['s_o_e_part'] = soe_parts

# Normalize earn over spend
total_eos = sum(earn_over_spend)
eos_parts = [x / total_eos for x in earn_over_spend]
monthly_ranks_df['e_o_s_score'] = earn_over_spend
monthly_ranks_df['e_o_s_part'] = eos_parts

# Normalize DAS
total_das = sum(monthly_ranks_df.number_of_das)
das_parts = monthly_ranks_df.number_of_das / total_das
monthly_ranks_df.insert(loc=4, value=das_parts, column='das_part')

# Normalize DAE
total_dae = sum(monthly_ranks_df.number_of_dae)
dae_parts = monthly_ranks_df.number_of_dae / total_dae
monthly_ranks_df.insert(loc=3, value=das_parts, column='dae_part')

# %% [markdown]
# ### Growth and Retention over Months

# %%
growth_counters_arr = []
for service_id in service_ids:
    res = get_service_timely_counters(service_id, time_start=two_months_ago, time_end=month_ago)
    res.pop('number_of_dae')
    res.pop('number_of_p2p')
    growth_counters_arr.append(res)

gr_ranks_df = pd.DataFrame(growth_counters_arr)
# display(gr_ranks_df)

gr_points = []
for ix, row in gr_ranks_df.iterrows():
    last_month_row = monthly_ranks_df.loc[monthly_ranks_df.digital_service_id == row.digital_service_id]
    last_month_das = last_month_row.number_of_das.iloc[0]
    
    if row.number_of_das > 0:
        gr_points.append(last_month_das / row.number_of_das)
    else:
        gr_points.append(0)

# Calculate part
total_gr = sum(gr_points)
g_and_r_part = gr_points/total_gr
        
monthly_ranks_df['prev_m_das']=gr_ranks_df['number_of_das']
monthly_ranks_df['g_and_r_score']=gr_points
monthly_ranks_df['g_and_r_part']=g_and_r_part

# %% [markdown]
# ## Charts

# %%
qgrid_wdget = qgrid.show_grid(monthly_ranks_df, show_toolbar=True)
qgrid_wdget

# %% [markdown]
# ## Export Data

# %%
monthly_ranks_df.head(1)

# %%
# Reduce to KRE scores columns only
kre_scores_df = monthly_ranks_df[['digital_service_id','name','dae_part','das_part', 'p2p_part', 'e_o_s_part', 's_o_e_part', 'g_and_r_part']]
csv_out_path = '{}/KRE_ranks.csv'.format(EXPORT_DATA_PATH)
kre_scores_df.sort_values(by=['name'], inplace=True)
kre_scores_df.to_csv(csv_out_path)
display(kre_scores_df)
print('Exported data to {}'.format(csv_out_path))

# %% [markdown]
# # Data Infrastructure Experminets
#
# Trying to consume big query using python

# %%
from google.cloud import bigquery
import pandas as pd

# %%
client = bigquery.Client()
query_job = client.query("""
        SELECT digital_service_id
          ,digital_service_name
          ,business_unit
    FROM `kin-bi.kin.digital_services_lookup_view`""")

results = query_job.result()  # Waits for job to complete.

# %%
results_pd = results.to_dataframe()
results_pd

# %% [markdown]
# # Test Functions for Production

# %%
import pandas as pd
from google.cloud import bigquery
from datetime import datetime
import logging

# %% [markdown]
# ## Google BQ Interface

# %%
def run_query(query_str):
    """
    Runs a query string on bigquery.
    Locks till end of results.
    Basic query string validation: length and not None
    """
    if not query_str:
        logger.error('Cannot execute query string: {}'.format(query_str))
        return None

    client = bigquery.Client()
    query_job = client.query(query_str)

    results = query_job.result()  # Waits for job to complete.
    df_result = results.to_dataframe()

    return df_result


def get_date_str_error(date_str, date_fmt='%Y-%m-%d'):
    """
    Validate a date string to be formated by a given format.
    It also validates the date exists.
    Returns ValueError (doesn't raise) if date is invalid.
    Returns None if date is OK.
    :param date_fmt: The format in which to validate the date '%Y-%m-%d'
    Example of valid date: 2016-02-29
    Example of invalid date: 2017-02-29
    """
    try:
        datetime.strptime(date_str, '%Y-%m-%d')
    except ValueError as err:
        return err
    return None


# PUBLIC METHODS ARE BYOND THIS LINE
# Everything above are internal private methods

# TODO: CACHE -> the resutls from this method should be cached by date.
def fetch_das_by_date(day='01', month='02', year='2019'):
    """
    Fetch DAS of all DS by a date given through parameters day, month and year
    Returns a pandas dataframe containing the result or
    None if there were problems
    """

    date_str = '{}-{}-{}'.fomrat(year, month, day)
    err = get_date_str_error(date_str)
    if err is not None:
        logger.error(
            'Failure parsing date day:{}, month:{}, year:{}. {}'.
            format(day, month, year, err))
        return None

    query_str = """
        SELECT * FROM `kin-bi.stellar.payments_with_tx_types_view`
        WHERE date = '{}' and
        tx_type IN ('spend','p2p')
        ORDER BY time
    """.format(date_str)

    return run_query(query_str)


# TODO: CACHE -> the resutls from this method should
# be cached by month-year ('%m-%Y).
def fetch_das_by_month(month, year=2019):
    if not month:
        logger.error('Cannot query given month: {}'.format(month))

    test_date_str = '{}-{}-1'.format(year, month)
    err = get_date_str_error(test_date_str)
    if err is not None:
        logger.error(
            'Failure parsing date month:{}, year:{}. {}'.
            format(month, year, err))
        return None

    query_str = """
        SELECT *
        FROM `kin-bi.stellar.payments_with_tx_types_view`
        WHERE EXTRACT(MONTH FROM time) = {} and
        EXTRACT(YEAR FROM time) = {} and
        tx_type IN ('spend','p2p')
    """.format(month, year)

    return run_query(query_str)


# TODO: CACHE -> cache key "ds:dev_program"
def developer_program_members():
    query_str = """
    SELECT *
    FROM `kin-bi.devprog.kdp_participants`
    """

    return run_query(query_str)

def list_of_all_devs(force_refresh = False):
    query_str = 'SELECT * FROM `kin-bi.kin.digital_services_lookup_view`'
    client = bigquery.Client()
    query_job = client.query(query_str)

    results = query_job.result()  # Waits for job to complete.
    all_devs_list = results.to_dataframe()
    
    return all_devs_list

# %% [markdown]
# ## Data Formatting

# %%
def monthly_das(month, year, only_dev_program=False):
    """
    Fetech Daily Active Spenders for each DS for a given month.
    """
    monthly_das = fetch_das_by_month(month, year)

    if only_dev_program:
        dev_program_list = developer_program_members()
        monthly_das = monthly_das[monthly_das['digital_service_id'].isin(dev_program_list['digital_service_id'])]

    interesting = monthly_das[['date', 'digital_service_name', 'amount']]
#     interesting.rename(inplace=True, columns={'amount':'num_of_tx'})
    interesting.columns = ['date', 'digital_service_name', 'number_of_transactions']
    grouped = interesting.groupby(['date', 'digital_service_name'])
    return grouped.count()

# %% [markdown]
# ## Charts bulding

# %%
# Platform Imports
import pandas as pd

# App imports
from kre.data.data_formater import monthly_das
from kre.infra.api_response import ApiResponse, ApiErrorResponse
from kre.infra.consts import KreApiCodes


class LeaderBoardResponse(ApiResponse):
    def __init__(self, ids=[], payouts=[]):
        super(LeaderBoardResponse, self).__init__()
        if len(ids) != len(payouts):
            errormsg = ('Failure calculating payouts, number of developers '
                        'is different from the number of payouts')
            raise ApiErrorResponse(errormsg, KreApiCodes.HTTP_500_INTERNAL_SERVER_ERROR)
        self.developer_ids = ids
        self.payouts = payouts


class KreLeaderBoard(object):
    def __init__(self):
        self.daily_das_for_month = None
        self.month = None
        self.year = None
        self.dev_p_only = None
        self.with_total = None

    def stam_empty_table():
        return LeaderBoardResponse()

    def stam_table():
        ids = ['uno', 'dos', 'tres']
        payouts = [12, 32, 12]
        return LeaderBoardResponse(ids=ids, payouts=payouts)

    def crash_table():
        ids = ['uno', 'dos', 'tres']
        payouts = [12, 12]
        return LeaderBoardResponse(ids=ids, payouts=payouts)

    def append_total(self, df, total_row_name='Total'):
        total_r = df.sum(numeric_only=True)
        total_r.name = total_row_name
        df_w_total = df.append(total_r)

        return df_w_total

    def leader_board_for_month(self, month='02', year='2019', only_dev_program=False, w_total=True):
        if self.month is None:
            self.month = month
            self.year = year
            self.dev_p_only = only_dev_program
            self.with_total = w_total
            new_request = True
        else:
            new_request = (self.month != month) or (self.year != year) or (self.dev_p_only != only_dev_program)

        if new_request:
            d_das_for_month = monthly_das(month, year, only_dev_program)
            self.daily_das_for_month = d_das_for_month

        flat_das = pd.DataFrame(self.daily_das_for_month.to_records())
        pivot_das = flat_das.pivot(index='digital_service_name', columns='date', values='number_of_transactions')
        if w_total:
            pivot_das = self.append_total(pivot_das)

        return pivot_das

    def leader_board_for_month_fractions(self, month='02', year='2019', only_dev_program=False):
        lead_board = self.leader_board_for_month(month=month,
                                                 year=year,
                                                 only_dev_program=only_dev_program,
                                                 w_total=True)

        fractions_df = lead_board.iloc[0:-2] / lead_board.iloc[-1]
        return fractions_df

    def payments_calculation(self,
                             daily_amount=100,
                             month='02',
                             year='2019',
                             only_dev_program=False):
        lead_fractions = self.leader_board_for_month_fractions(month=month,
                                                               year=year,
                                                               only_dev_program=only_dev_program)
        lead_fractions = lead_fractions.fillna(0)
        payments = lead_fractions * daily_amount
        payments = self.append_total(payments)
        return payments

# %%
month_das = fetch_das_by_month(11, 2018)

# %%
display(month_das.head(5))
interesting = month_das[['date', 'digital_service_name', 'amount']]
grouped = month_das.groupby(['date', 'digital_service_name'])
grp_sum = grouped.sum()
grp_count = grouped.count()
display(grp_sum.head(30))
display(grp_count.head(30))
# Out:
#          date                                             source  \
# 0  2018-11-14  GAYVEIXJVHVWHKL67VM7GUTWOOEOMROKR7VAAHMHOK3SXZ...
# 1  2018-11-14  GBLCSS5BWEMVGTVV6EZ4UHMPH5FZ6ZB4WHVHUUVRLOKZYM...
# 2  2018-11-14  GD6UDTJJ4T7XMAVYEIFRIGX3MHD5D55BLJDUUO6ATRFOE3...
# 3  2018-11-14  GD6ZEYGELF5RBW43C7PXI5VK7QDCRWL6RESRIHAXZ3BPG5...
# 4  2018-11-14  GAF6YVMB7LO6R3AVD6JX72PL7QW5KI53O5UJDYOG4V5MHS...
#
#                                          destination  amount  \
# 0  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...     2.0
# 1  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...     2.0
# 2  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...     2.0
# 3  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...     2.0
# 4  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...     2.0
#
#                       memo_text  \
# 0  1-p365-THu6fQoSLgxsk4X4yksxO
# 1  1-p365-TFpj8exLIHnB5O6AUQRRQ
# 2  1-p365-TFiARJsRhsIrpC75NRP7r
# 3  1-p365-THvH0AzGTl4tmmmZJ0IvC
# 4  1-p365-TTjnFlB8xLgEQrccsRGmg
#
#                                                 hash  \
# 0  76f2fb9f649d0dd1164b53b35e1b655b2918c4de4e0a2e...
# 1  7db8f100f658346d6e8ab43f1d3e813e056a7f4745d884...
# 2  c5c32dfef685e2b7ec62c7584e837791c1255c4f88503a...
# 3  341043631447ba5e7a09374e2f7db686fa770e794df088...
# 4  ae007d922ff8765a4581846f0e5fc5e37e53622616fc32...
#
#                        time memo_protocol digital_service_id  \
# 0 2018-11-14 00:00:58+00:00             1               p365
# 1 2018-11-14 00:01:02+00:00             1               p365
# 2 2018-11-14 00:01:23+00:00             1               p365
# 3 2018-11-14 00:02:02+00:00             1               p365
# 4 2018-11-14 00:02:02+00:00             1               p365
#
#               tx_details digital_service_name business_unit  \
# 0  THu6fQoSLgxsk4X4yksxO                 p365     Ecosystem
# 1  TFpj8exLIHnB5O6AUQRRQ                 p365     Ecosystem
# 2  TFiARJsRhsIrpC75NRP7r                 p365     Ecosystem
# 3  THvH0AzGTl4tmmmZJ0IvC                 p365     Ecosystem
# 4  TTjnFlB8xLgEQrccsRGmg                 p365     Ecosystem
#
#                                    app_wallet_sender  \
# 0  GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 1  GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 2  GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 3  GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 4  GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
#
#                                 app_wallet_recipient app_wallet_sender_2  \
# 0  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
# 1  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
# 2  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
# 3  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
# 4  GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
#
#   app_wallet_recipient_2 tx_type  \
# 0                          spend
# 1                          spend
# 2                          spend
# 3                          spend
# 4                          spend
#
#                                       user_wallet_id
# 0  GAYVEIXJVHVWHKL67VM7GUTWOOEOMROKR7VAAHMHOK3SXZ...
# 1  GBLCSS5BWEMVGTVV6EZ4UHMPH5FZ6ZB4WHVHUUVRLOKZYM...
# 2  GD6UDTJJ4T7XMAVYEIFRIGX3MHD5D55BLJDUUO6ATRFOE3...
# 3  GD6ZEYGELF5RBW43C7PXI5VK7QDCRWL6RESRIHAXZ3BPG5...
# 4  GAF6YVMB7LO6R3AVD6JX72PL7QW5KI53O5UJDYOG4V5MHS...
#                                       amount
# date       digital_service_name
# 2018-11-01 Blastchat                   265.0
#            Coin Fantasy                 10.0
#            Find - Find travelers        30.0
#            GoChallengeMe.club          123.0
#            Kimeo                        56.0
#            KinTipBot                 17955.0
#            Kinguist                   8790.0
#            Kinit                    152067.0
#            Nearby                     4853.0
#            Pause For                 36500.0
#            Rave                          2.0
#            Vent                       6900.0
#            anonymous              25000000.0
#            kik                       10200.0
#            p365                      11294.0
# 2018-11-02 Blastchat                   322.0
#            Find - Find travelers        10.0
#            GoChallengeMe.club           69.0
#            Kimeo                        64.0
#            KinQuest                     10.0
#            KinTipBot                 51606.0
#            Kinguist                  17745.0
#            Kinit                     37400.0
#            Nearby                     2850.0
#            Pause For                 27500.0
#            Vent                       9600.0
#            kik                       11500.0
#            p365                      10752.0
# 2018-11-03 Blastchat                   482.0
#            Find - Find travelers        25.0
#                                   source  destination  amount  memo_text  \
# date       digital_service_name
# 2018-11-01 Blastchat                 226          226     226        226
#            Coin Fantasy                1            1       1          1
#            Find - Find travelers       6            6       6          6
#            GoChallengeMe.club         16           16      16         16
#            Kimeo                       5            5       5          5
#            KinTipBot                 299          299     299        299
#            Kinguist                   55           55      55         55
#            Kinit                     227          227     227        227
#            Nearby                    116          116     116        116
#            Pause For                  45           45      45         45
#            Rave                        2            2       2          2
#            Vent                       69           69      69         69
#            anonymous                   1            1       1          1
#            kik                       102          102     102        102
#            p365                     3169         3169    3169       3169
# 2018-11-02 Blastchat                 182          182     182        182
#            Find - Find travelers       2            2       2          2
#            GoChallengeMe.club          4            4       4          4
#            Kimeo                       7            7       7          7
#            KinQuest                    1            1       1          1
#            KinTipBot                 451          451     451        451
#            Kinguist                  101          101     101        101
#            Kinit                      61           61      61         61
#            Nearby                     71           71      71         71
#            Pause For                  27           27      27         27
#            Vent                       96           96      96         96
#            kik                       115          115     115        115
#            p365                     4381         4381    4381       4381
# 2018-11-03 Blastchat                 263          263     263        263
#            Find - Find travelers       5            5       5          5
#
#                                   hash  time  memo_protocol  \
# date       digital_service_name
# 2018-11-01 Blastchat               226   226            226
#            Coin Fantasy              1     1              1
#            Find - Find travelers     6     6              6
#            GoChallengeMe.club       16    16             16
#            Kimeo                     5     5              5
#            KinTipBot               299   299            299
#            Kinguist                 55    55             55
#            Kinit                   227   227            227
#            Nearby                  116   116            116
#            Pause For                45    45             45
#            Rave                      2     2              2
#            Vent                     69    69             69
#            anonymous                 1     1              1
#            kik                     102   102            102
#            p365                   3169  3169           3169
# 2018-11-02 Blastchat               182   182            182
#            Find - Find travelers     2     2              2
#            GoChallengeMe.club        4     4              4
#            Kimeo                     7     7              7
#            KinQuest                  1     1              1
#            KinTipBot               451   451            451
#            Kinguist                101   101            101
#            Kinit                    61    61             61
#            Nearby                   71    71             71
#            Pause For                27    27             27
#            Vent                     96    96             96
#            kik                     115   115            115
#            p365                   4381  4381           4381
# 2018-11-03 Blastchat               263   263            263
#            Find - Find travelers     5     5              5
#
#                                   digital_service_id  tx_details  \
# date       digital_service_name
# 2018-11-01 Blastchat                             226         226
#            Coin Fantasy                            1           1
#            Find - Find travelers                   6           6
#            GoChallengeMe.club                     16          16
#            Kimeo                                   5           5
#            KinTipBot                             299         299
#            Kinguist                               55          55
#            Kinit                                 227         227
#            Nearby                                116         116
#            Pause For                              45          45
#            Rave                                    2           2
#            Vent                                   69          69
#            anonymous                               1           1
#            kik                                   102         102
#            p365                                 3169        3169
# 2018-11-02 Blastchat                             182         182
#            Find - Find travelers                   2           2
#            GoChallengeMe.club                      4           4
#            Kimeo                                   7           7
#            KinQuest                                1           1
#            KinTipBot                             451         451
#            Kinguist                              101         101
#            Kinit                                  61          61
#            Nearby                                 71          71
#            Pause For                              27          27
#            Vent                                   96          96
#            kik                                   115         115
#            p365                                 4381        4381
# 2018-11-03 Blastchat                             263         263
#            Find - Find travelers                   5           5
#
#                                   business_unit  app_wallet_sender  \
# date       digital_service_name
# 2018-11-01 Blastchat                        226                226
#            Coin Fantasy                       1                  1
#            Find - Find travelers              6                  6
#            GoChallengeMe.club                16                 16
#            Kimeo                              5                  5
#            KinTipBot                        299                299
#            Kinguist                          55                 55
#            Kinit                            227                227
#            Nearby                           116                116
#            Pause For                         45                 45
#            Rave                               2                  2
#            Vent                              69                 69
#            anonymous                          1                  1
#            kik                              102                102
#            p365                            3169               3169
# 2018-11-02 Blastchat                        182                182
#            Find - Find travelers              2                  2
#            GoChallengeMe.club                 4                  4
#            Kimeo                              7                  7
#            KinQuest                           1                  1
#            KinTipBot                        451                451
#            Kinguist                         101                101
#            Kinit                             61                 61
#            Nearby                            71                 71
#            Pause For                         27                 27
#            Vent                              96                 96
#            kik                              115                115
#            p365                            4381               4381
# 2018-11-03 Blastchat                        263                263
#            Find - Find travelers              5                  5
#
#                                   app_wallet_recipient  app_wallet_sender_2  \
# date       digital_service_name
# 2018-11-01 Blastchat                               226                  226
#            Coin Fantasy                              1                    1
#            Find - Find travelers                     6                    6
#            GoChallengeMe.club                       16                   16
#            Kimeo                                     5                    5
#            KinTipBot                               299                  299
#            Kinguist                                 55                   55
#            Kinit                                   227                  227
#            Nearby                                  116                  116
#            Pause For                                45                   45
#            Rave                                      2                    2
#            Vent                                     69                   69
#            anonymous                                 1                    1
#            kik                                     102                  102
#            p365                                   3169                 3169
# 2018-11-02 Blastchat                               182                  182
#            Find - Find travelers                     2                    2
#            GoChallengeMe.club                        4                    4
#            Kimeo                                     7                    7
#            KinQuest                                  1                    1
#            KinTipBot                               451                  451
#            Kinguist                                101                  101
#            Kinit                                    61                   61
#            Nearby                                   71                   71
#            Pause For                                27                   27
#            Vent                                     96                   96
#            kik                                     115                  115
#            p365                                   4381                 4381
# 2018-11-03 Blastchat                               263                  263
#            Find - Find travelers                     5                    5
#
#                                   app_wallet_recipient_2  tx_type  \
# date       digital_service_name
# 2018-11-01 Blastchat                                   0      226
#            Coin Fantasy                                0        1
#            Find - Find travelers                       0        6
#            GoChallengeMe.club                          0       16
#            Kimeo                                       0        5
#            KinTipBot                                   0      299
#            Kinguist                                    0       55
#            Kinit                                     227      227
#            Nearby                                      0      116
#            Pause For                                   0       45
#            Rave                                        0        2
#            Vent                                        0       69
#            anonymous                                   1        1
#            kik                                       102      102
#            p365                                     3169     3169
# 2018-11-02 Blastchat                                   0      182
#            Find - Find travelers                       0        2
#            GoChallengeMe.club                          0        4
#            Kimeo                                       0        7
#            KinQuest                                    0        1
#            KinTipBot                                   0      451
#            Kinguist                                    0      101
#            Kinit                                      61       61
#            Nearby                                      0       71
#            Pause For                                   0       27
#            Vent                                        0       96
#            kik                                       115      115
#            p365                                     4381     4381
# 2018-11-03 Blastchat                                   0      263
#            Find - Find travelers                       0        5
#
#                                   user_wallet_id
# date       digital_service_name
# 2018-11-01 Blastchat                         226
#            Coin Fantasy                        1
#            Find - Find travelers               6
#            GoChallengeMe.club                 16
#            Kimeo                               5
#            KinTipBot                         299
#            Kinguist                           55
#            Kinit                             227
#            Nearby                            116
#            Pause For                          45
#            Rave                                2
#            Vent                               69
#            anonymous                           1
#            kik                               102
#            p365                             3169
# 2018-11-02 Blastchat                         182
#            Find - Find travelers               2
#            GoChallengeMe.club                  4
#            Kimeo                               7
#            KinQuest                            1
#            KinTipBot                         451
#            Kinguist                          101
#            Kinit                              61
#            Nearby                             71
#            Pause For                          27
#            Vent                               96
#            kik                               115
#            p365                             4381
# 2018-11-03 Blastchat                         263
#            Find - Find travelers               5

# %%
developer_program_members = developer_program_members()

# %%
display(developer_program_members)

# %%
dev_prog_DAS = fetch_monthly_das(2, 2019, only_dev_program=True)

# %%
display(dev_prog_DAS.head(30))

# %% [markdown]
# ### Flattenning test

# %%
# flat = leader_board_for_month(month='02', year='2019', only_dev_program=True)
lb = KreLeaderBoard()
res = lb.leader_board_for_month_fractions(month='02', year='2019', only_dev_program=True)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                      number_of_transactions
# (2019-02-01, Blastchat )                                124
# (2019-02-01, GoChallengeMe.club)                          3
# (2019-02-01, KinTipBot)                                  76
# (2019-02-01, Kinetik)                                     1
# (2019-02-01, Nearby)                                   1089
# (2019-02-01, Pause For)                                  24
# (2019-02-01, Rave)                                      797
# (2019-02-01, ThisThat)                                    1
# (2019-02-01, Trivia Clan)                                 1
# (2019-02-01, Vent)                                      301
# (2019-02-01, pop.in)                                    145
# (2019-02-02, Blastchat )                                119
# (2019-02-02, Coin Fantasy)                                3
# (2019-02-02, Find - Find travelers)                       5
# (2019-02-02, GoChallengeMe.club)                          6
# (2019-02-02, KinTipBot)                                  76
# (2019-02-02, Kinetik)                                     1
# (2019-02-02, Nearby)                                    824
# (2019-02-02, Pause For)                                  42
# (2019-02-02, Rave)                                      654
# (2019-02-02, RealityChainARC)                             2
# (2019-02-02, Rock Paper Scissors)                         2
# (2019-02-02, Vent)                                      265
# (2019-02-02, pop.in)                                    212
# (2019-02-03, Blastchat )                                104
# (2019-02-03, ChatSwapDitch)                               1
# (2019-02-03, KIN VPN)                                     3
# (2019-02-03, KinTipBot)                                  59
# (2019-02-03, Nearby)                                    769
# (2019-02-03, Pause For)                                  21
# ...                                                     ...
# (2019-02-08, Pause For)                                   9
# (2019-02-08, Rave)                                      331
# (2019-02-08, ThisThat)                                    3
# (2019-02-08, Vent)                                      216
# (2019-02-08, pop.in)                                    168
# (2019-02-09, Blastchat )                                 68
# (2019-02-09, ChatSwapDitch)                               1
# (2019-02-09, Find - Find travelers)                       1
# (2019-02-09, GoChallengeMe.club)                          1
# (2019-02-09, KinTipBot)                                  35
# (2019-02-09, Klicktion)                                   1
# (2019-02-09, Nearby)                                   1002
# (2019-02-09, Pause For)                                  13
# (2019-02-09, Rave)                                      373
# (2019-02-09, Rock Paper Scissors)                         2
# (2019-02-09, ThisThat)                                    1
# (2019-02-09, Trivia Clan)                                 1
# (2019-02-09, Vent)                                      187
# (2019-02-09, pop.in)                                    333
# (2019-02-10, Blastchat )                                 84
# (2019-02-10, ChatSwapDitch)                               1
# (2019-02-10, Find - Find travelers)                       3
# (2019-02-10, GoChallengeMe.club)                          2
# (2019-02-10, KinTipBot)                                  35
# (2019-02-10, Nearby)                                    873
# (2019-02-10, Pause For)                                  33
# (2019-02-10, Rave)                                     1199
# (2019-02-10, Vent)                                      206
# (2019-02-10, pop.in)                                    129
# Total                                                 20554
#
# [108 rows x 1 columns]
# ##############################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-11-ac54602a5361> in <module>
#       1 # flat = leader_board_for_month(month='02', year='2019', only_dev_program=True)
#       2 lb = KreLeaderBoard()
# ----> 3 res = lb.leader_board_for_month_fractions(month='02', year='2019', only_dev_program=True)
#
# <ipython-input-8-333e47b1707e> in leader_board_for_month_fractions(self, month, year, only_dev_program, w_total)
#      59                                                  year=year,
#      60                                                  only_dev_program=only_dev_program,
# ---> 61                                                  w_total=w_total)
#      62
#      63         fractions_df = lead_board.iloc[0:-2] / lead_board.iloc[-1]
#
# <ipython-input-8-333e47b1707e> in leader_board_for_month(self, month, year, only_dev_program, w_total)
#      49         display(self.daily_das_for_month)
#      50         print('#####'*454)
# ---> 51         display(flat_das)
#      52         print('+++++'*434)
#      53         flat_das = pd.DataFrame(self.daily_das_for_month.to_records())
#
# UnboundLocalError: local variable 'flat_das' referenced before assignment

# %%
flat = flat.fillna(0)
display(flat)

# %%
total_r = flat.sum(numeric_only=True)
display(total_r)
total_r.name = 'total'
# flat_w_total = flat.append(total_r, ignore_index=True)
flat_w_total = flat.append(total_r)
# flat_w_total = flat.append(flat.sum(numeric_only=True), ignore_index=True)
display(flat_w_total)

# %%
percents = flat_w_total.iloc[0:-2]/flat_w_total.iloc[-1]
display(percents)

# %% [markdown]
# ### Use exported CSV

# %%
TEST_CSV_PATH='~/Dev/'
udas = pd.read_csv('{}fractions.csv'.format(TEST_CSV_PATH))
# udas = pd.read_csv('{}uDAS.csv'.format(TEST_CSV_PATH))
udas.set_index('digital_service_id', inplace=True)

# %%
display(udas)
# Out:
#                     2018-11-01  2018-11-02  2018-11-03  2018-11-04  \
# digital_service_id
# 2bpx                  0.000000    0.000000    0.000000    0.004454
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.000000    0.000000    0.000000
# 8onm                  0.001721    0.008929    0.000000    0.002227
# 8vlz                  0.144578    0.086310    0.161074    0.227171
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.000000    0.000000    0.001678    0.004454
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.058520    0.061012    0.035235    0.044543
# h43v                  0.001721    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.110155    0.127976    0.125839    0.129176
# l83h                  0.001721    0.000000    0.000000    0.004454
# lsff                  0.000000    0.000000    0.000000    0.000000
# lx6f                  0.000000    0.001488    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.049914    0.031250    0.035235    0.040089
# rced                  0.449225    0.514881    0.370805    0.318486
# ujti                  0.165232    0.159226    0.250000    0.195991
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.008606    0.002976    0.008389    0.002227
# ysa7                  0.000000    0.000000    0.000000    0.000000
# ze6y                  0.008606    0.005952    0.011745    0.026726
#
#                     2018-11-05  2018-11-06  2018-11-07  2018-11-08  \
# digital_service_id
# 2bpx                  0.027638    0.069767    0.017544    0.007547
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.004651    0.007018    0.003774
# 8onm                  0.012563    0.025581    0.024561    0.020755
# 8vlz                  0.188442    0.130233    0.133333    0.318868
# 96h9                  0.000000    0.000000    0.000000    0.001887
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.007538    0.000000    0.003509    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.020101    0.023256    0.010526    0.007547
# h43v                  0.000000    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.003774
# kcyg                  0.000000    0.000000    0.000000    0.001887
# l68b                  0.153266    0.086047    0.091228    0.273585
# l83h                  0.000000    0.000000    0.000000    0.000000
# lsff                  0.000000    0.000000    0.000000    0.001887
# lx6f                  0.005025    0.000000    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.050251    0.058140    0.049123    0.030189
# rced                  0.316583    0.360465    0.382456    0.181132
# ujti                  0.208543    0.230233    0.266667    0.118868
# yjzv                  0.000000    0.000000    0.000000    0.003774
# yqyf                  0.005025    0.009302    0.003509    0.000000
# ysa7                  0.000000    0.000000    0.003509    0.022642
# ze6y                  0.005025    0.002326    0.007018    0.001887
#
#                     2018-11-09  2018-11-10     ...      2018-11-21  \
# digital_service_id                             ...
# 2bpx                  0.005469    0.002860     ...        0.003375
# 39zx                  0.003646    0.000000     ...        0.000000
# 3tnn                  0.007293    0.018112     ...        0.178853
# 8onm                  0.007293    0.009533     ...        0.003375
# 8vlz                  0.577940    0.611058     ...        0.403825
# 96h9                  0.002735    0.000953     ...        0.000000
# bof3                  0.000000    0.000000     ...        0.003375
# c2jf                  0.004558    0.000953     ...        0.002250
# ch21                  0.000000    0.000000     ...        0.000000
# fx60                  0.004558    0.002860     ...        0.000000
# g58b                  0.000000    0.000000     ...        0.000000
# gg38                  0.000000    0.000000     ...        0.003375
# ghik                  0.001823    0.011439     ...        0.000000
# h43v                  0.000000    0.000000     ...        0.000000
# iwfn                  0.000000    0.000000     ...        0.001125
# j732                  0.000000    0.000000     ...        0.000000
# kcyg                  0.000000    0.000000     ...        0.000000
# l68b                  0.186873    0.171592     ...        0.134983
# l83h                  0.000912    0.000000     ...        0.047244
# lsff                  0.000000    0.000000     ...        0.019123
# lx6f                  0.000000    0.000000     ...        0.000000
# nerb                  0.000000    0.000000     ...        0.003375
# pgbv                  0.014585    0.019066     ...        0.016873
# rced                  0.107566    0.083889     ...        0.103487
# ujti                  0.061076    0.059104     ...        0.073116
# yjzv                  0.000000    0.000000     ...        0.001125
# yqyf                  0.004558    0.001907     ...        0.000000
# ysa7                  0.007293    0.005720     ...        0.000000
# ze6y                  0.001823    0.000953     ...        0.001125
#
#                     2018-11-22  2018-11-23  2018-11-24  2018-11-25  \
# digital_service_id
# 2bpx                  0.001274    0.000000    0.014344    0.003503
# 39zx                  0.001274    0.000000    0.000000    0.000000
# 3tnn                  0.180892    0.102662    0.054303    0.057793
# 8onm                  0.002548    0.000000    0.002049    0.001751
# 8vlz                  0.391083    0.366920    0.564549    0.350263
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.001274    0.001901    0.004098    0.001751
# c2jf                  0.003822    0.000000    0.001025    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.003822    0.001901    0.004098    0.003503
# g58b                  0.000000    0.000000    0.000000    0.001751
# gg38                  0.001274    0.001901    0.001025    0.003503
# ghik                  0.001274    0.000000    0.001025    0.007005
# h43v                  0.002548    0.000000    0.000000    0.000000
# iwfn                  0.003822    0.000000    0.000000    0.001751
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.124841    0.205323    0.148566    0.225919
# l83h                  0.040764    0.053232    0.030738    0.085814
# lsff                  0.022930    0.000000    0.004098    0.021016
# lx6f                  0.000000    0.000000    0.000000    0.000000
# nerb                  0.000000    0.005703    0.000000    0.001751
# pgbv                  0.019108    0.036122    0.013320    0.021016
# rced                  0.091720    0.115970    0.091189    0.077058
# ujti                  0.104459    0.104563    0.065574    0.127846
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.000000    0.000000    0.000000    0.000000
# ysa7                  0.000000    0.000000    0.000000    0.000000
# ze6y                  0.001274    0.003802    0.000000    0.007005
#
#                     2018-11-26  2018-11-27  2018-11-28  2018-11-29  2018-11-30
# digital_service_id
# 2bpx                  0.003067    0.001199    0.002740    0.001623      0.0000
# 39zx                  0.000000    0.000000    0.000000    0.000000      0.0000
# 3tnn                  0.049080    0.022782    0.027397    0.021104      0.0256
# 8onm                  0.000000    0.000000    0.000000    0.003247      0.0000
# 8vlz                  0.217791    0.425659    0.493151    0.498377      0.4816
# 96h9                  0.000000    0.000000    0.000000    0.000000      0.0000
# bof3                  0.000000    0.000000    0.000000    0.001623      0.0000
# c2jf                  0.000000    0.001199    0.002740    0.001623      0.0000
# ch21                  0.000000    0.000000    0.000000    0.000000      0.0000
# fx60                  0.009202    0.003597    0.002740    0.004870      0.0048
# g58b                  0.000000    0.000000    0.002740    0.000000      0.0000
# gg38                  0.003067    0.000000    0.004110    0.000000      0.0016
# ghik                  0.000000    0.000000    0.001370    0.001623      0.0000
# h43v                  0.000000    0.000000    0.000000    0.000000      0.0000
# iwfn                  0.003067    0.001199    0.000000    0.000000      0.0016
# j732                  0.000000    0.000000    0.000000    0.000000      0.0000
# kcyg                  0.000000    0.000000    0.000000    0.000000      0.0000
# l68b                  0.319018    0.128297    0.124658    0.163961      0.1600
# l83h                  0.098160    0.081535    0.097260    0.060065      0.1008
# lsff                  0.033742    0.009592    0.015068    0.021104      0.0176
# lx6f                  0.000000    0.000000    0.000000    0.000000      0.0000
# nerb                  0.003067    0.000000    0.000000    0.000000      0.0000
# pgbv                  0.049080    0.021583    0.017808    0.014610      0.0208
# rced                  0.104294    0.229017    0.120548    0.142857      0.1344
# ujti                  0.104294    0.070743    0.083562    0.063312      0.0496
# yjzv                  0.003067    0.001199    0.001370    0.000000      0.0016
# yqyf                  0.000000    0.000000    0.000000    0.000000      0.0000
# ysa7                  0.000000    0.000000    0.000000    0.000000      0.0000
# ze6y                  0.000000    0.002398    0.002740    0.000000      0.0000
#
# [29 rows x 30 columns]

# %%
display(udas.iloc[0:-1])
# Out:
#                     2018-11-01  2018-11-02  2018-11-03  2018-11-04  \
# digital_service_id
# 2bpx                  0.000000    0.000000    0.000000    0.004454
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.000000    0.000000    0.000000
# 8onm                  0.001721    0.008929    0.000000    0.002227
# 8vlz                  0.144578    0.086310    0.161074    0.227171
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.000000    0.000000    0.001678    0.004454
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.058520    0.061012    0.035235    0.044543
# h43v                  0.001721    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.110155    0.127976    0.125839    0.129176
# l83h                  0.001721    0.000000    0.000000    0.004454
# lsff                  0.000000    0.000000    0.000000    0.000000
# lx6f                  0.000000    0.001488    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.049914    0.031250    0.035235    0.040089
# rced                  0.449225    0.514881    0.370805    0.318486
# ujti                  0.165232    0.159226    0.250000    0.195991
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.008606    0.002976    0.008389    0.002227
# ysa7                  0.000000    0.000000    0.000000    0.000000
#
#                     2018-11-05  2018-11-06  2018-11-07  2018-11-08  \
# digital_service_id
# 2bpx                  0.027638    0.069767    0.017544    0.007547
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.004651    0.007018    0.003774
# 8onm                  0.012563    0.025581    0.024561    0.020755
# 8vlz                  0.188442    0.130233    0.133333    0.318868
# 96h9                  0.000000    0.000000    0.000000    0.001887
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.007538    0.000000    0.003509    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.020101    0.023256    0.010526    0.007547
# h43v                  0.000000    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.003774
# kcyg                  0.000000    0.000000    0.000000    0.001887
# l68b                  0.153266    0.086047    0.091228    0.273585
# l83h                  0.000000    0.000000    0.000000    0.000000
# lsff                  0.000000    0.000000    0.000000    0.001887
# lx6f                  0.005025    0.000000    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.050251    0.058140    0.049123    0.030189
# rced                  0.316583    0.360465    0.382456    0.181132
# ujti                  0.208543    0.230233    0.266667    0.118868
# yjzv                  0.000000    0.000000    0.000000    0.003774
# yqyf                  0.005025    0.009302    0.003509    0.000000
# ysa7                  0.000000    0.000000    0.003509    0.022642
#
#                     2018-11-09  2018-11-10     ...      2018-11-21  \
# digital_service_id                             ...
# 2bpx                  0.005469    0.002860     ...        0.003375
# 39zx                  0.003646    0.000000     ...        0.000000
# 3tnn                  0.007293    0.018112     ...        0.178853
# 8onm                  0.007293    0.009533     ...        0.003375
# 8vlz                  0.577940    0.611058     ...        0.403825
# 96h9                  0.002735    0.000953     ...        0.000000
# bof3                  0.000000    0.000000     ...        0.003375
# c2jf                  0.004558    0.000953     ...        0.002250
# ch21                  0.000000    0.000000     ...        0.000000
# fx60                  0.004558    0.002860     ...        0.000000
# g58b                  0.000000    0.000000     ...        0.000000
# gg38                  0.000000    0.000000     ...        0.003375
# ghik                  0.001823    0.011439     ...        0.000000
# h43v                  0.000000    0.000000     ...        0.000000
# iwfn                  0.000000    0.000000     ...        0.001125
# j732                  0.000000    0.000000     ...        0.000000
# kcyg                  0.000000    0.000000     ...        0.000000
# l68b                  0.186873    0.171592     ...        0.134983
# l83h                  0.000912    0.000000     ...        0.047244
# lsff                  0.000000    0.000000     ...        0.019123
# lx6f                  0.000000    0.000000     ...        0.000000
# nerb                  0.000000    0.000000     ...        0.003375
# pgbv                  0.014585    0.019066     ...        0.016873
# rced                  0.107566    0.083889     ...        0.103487
# ujti                  0.061076    0.059104     ...        0.073116
# yjzv                  0.000000    0.000000     ...        0.001125
# yqyf                  0.004558    0.001907     ...        0.000000
# ysa7                  0.007293    0.005720     ...        0.000000
#
#                     2018-11-22  2018-11-23  2018-11-24  2018-11-25  \
# digital_service_id
# 2bpx                  0.001274    0.000000    0.014344    0.003503
# 39zx                  0.001274    0.000000    0.000000    0.000000
# 3tnn                  0.180892    0.102662    0.054303    0.057793
# 8onm                  0.002548    0.000000    0.002049    0.001751
# 8vlz                  0.391083    0.366920    0.564549    0.350263
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.001274    0.001901    0.004098    0.001751
# c2jf                  0.003822    0.000000    0.001025    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.003822    0.001901    0.004098    0.003503
# g58b                  0.000000    0.000000    0.000000    0.001751
# gg38                  0.001274    0.001901    0.001025    0.003503
# ghik                  0.001274    0.000000    0.001025    0.007005
# h43v                  0.002548    0.000000    0.000000    0.000000
# iwfn                  0.003822    0.000000    0.000000    0.001751
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.124841    0.205323    0.148566    0.225919
# l83h                  0.040764    0.053232    0.030738    0.085814
# lsff                  0.022930    0.000000    0.004098    0.021016
# lx6f                  0.000000    0.000000    0.000000    0.000000
# nerb                  0.000000    0.005703    0.000000    0.001751
# pgbv                  0.019108    0.036122    0.013320    0.021016
# rced                  0.091720    0.115970    0.091189    0.077058
# ujti                  0.104459    0.104563    0.065574    0.127846
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.000000    0.000000    0.000000    0.000000
# ysa7                  0.000000    0.000000    0.000000    0.000000
#
#                     2018-11-26  2018-11-27  2018-11-28  2018-11-29  2018-11-30
# digital_service_id
# 2bpx                  0.003067    0.001199    0.002740    0.001623      0.0000
# 39zx                  0.000000    0.000000    0.000000    0.000000      0.0000
# 3tnn                  0.049080    0.022782    0.027397    0.021104      0.0256
# 8onm                  0.000000    0.000000    0.000000    0.003247      0.0000
# 8vlz                  0.217791    0.425659    0.493151    0.498377      0.4816
# 96h9                  0.000000    0.000000    0.000000    0.000000      0.0000
# bof3                  0.000000    0.000000    0.000000    0.001623      0.0000
# c2jf                  0.000000    0.001199    0.002740    0.001623      0.0000
# ch21                  0.000000    0.000000    0.000000    0.000000      0.0000
# fx60                  0.009202    0.003597    0.002740    0.004870      0.0048
# g58b                  0.000000    0.000000    0.002740    0.000000      0.0000
# gg38                  0.003067    0.000000    0.004110    0.000000      0.0016
# ghik                  0.000000    0.000000    0.001370    0.001623      0.0000
# h43v                  0.000000    0.000000    0.000000    0.000000      0.0000
# iwfn                  0.003067    0.001199    0.000000    0.000000      0.0016
# j732                  0.000000    0.000000    0.000000    0.000000      0.0000
# kcyg                  0.000000    0.000000    0.000000    0.000000      0.0000
# l68b                  0.319018    0.128297    0.124658    0.163961      0.1600
# l83h                  0.098160    0.081535    0.097260    0.060065      0.1008
# lsff                  0.033742    0.009592    0.015068    0.021104      0.0176
# lx6f                  0.000000    0.000000    0.000000    0.000000      0.0000
# nerb                  0.003067    0.000000    0.000000    0.000000      0.0000
# pgbv                  0.049080    0.021583    0.017808    0.014610      0.0208
# rced                  0.104294    0.229017    0.120548    0.142857      0.1344
# ujti                  0.104294    0.070743    0.083562    0.063312      0.0496
# yjzv                  0.003067    0.001199    0.001370    0.000000      0.0016
# yqyf                  0.000000    0.000000    0.000000    0.000000      0.0000
# ysa7                  0.000000    0.000000    0.000000    0.000000      0.0000
#
# [28 rows x 30 columns]

# %%
fractions_df = udas.iloc[0:-1] / udas.iloc[-1]
total_r = fractions_df.sum(numeric_only=True)
total_r.name = 'Total'
fractions_df = fractions_df.append(total_r)

display(fractions_df)
# Out:
#                     2018-11-01  2018-11-02  2018-11-03  2018-11-04  \
# digital_service_id
# 2bpx                  0.000000    0.000000    0.000000    0.004454
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.000000    0.000000    0.000000
# 8onm                  0.001721    0.008929    0.000000    0.002227
# 8vlz                  0.144578    0.086310    0.161074    0.227171
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.000000    0.000000    0.001678    0.004454
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.058520    0.061012    0.035235    0.044543
# h43v                  0.001721    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.110155    0.127976    0.125839    0.129176
# l83h                  0.001721    0.000000    0.000000    0.004454
# lsff                  0.000000    0.000000    0.000000    0.000000
# lx6f                  0.000000    0.001488    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.049914    0.031250    0.035235    0.040089
# rced                  0.449225    0.514881    0.370805    0.318486
# ujti                  0.165232    0.159226    0.250000    0.195991
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.008606    0.002976    0.008389    0.002227
# ysa7                  0.000000    0.000000    0.000000    0.000000
# ze6y                  0.008606    0.005952    0.011745    0.026726
# Total                 1.000000    1.000000    1.000000    1.000000
#
#                     2018-11-05  2018-11-06  2018-11-07  2018-11-08  \
# digital_service_id
# 2bpx                  0.027638    0.069767    0.017544    0.007547
# 39zx                  0.000000    0.000000    0.000000    0.000000
# 3tnn                  0.000000    0.004651    0.007018    0.003774
# 8onm                  0.012563    0.025581    0.024561    0.020755
# 8vlz                  0.188442    0.130233    0.133333    0.318868
# 96h9                  0.000000    0.000000    0.000000    0.001887
# bof3                  0.000000    0.000000    0.000000    0.000000
# c2jf                  0.007538    0.000000    0.003509    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.000000    0.000000    0.000000    0.000000
# g58b                  0.000000    0.000000    0.000000    0.000000
# gg38                  0.000000    0.000000    0.000000    0.000000
# ghik                  0.020101    0.023256    0.010526    0.007547
# h43v                  0.000000    0.000000    0.000000    0.000000
# iwfn                  0.000000    0.000000    0.000000    0.000000
# j732                  0.000000    0.000000    0.000000    0.003774
# kcyg                  0.000000    0.000000    0.000000    0.001887
# l68b                  0.153266    0.086047    0.091228    0.273585
# l83h                  0.000000    0.000000    0.000000    0.000000
# lsff                  0.000000    0.000000    0.000000    0.001887
# lx6f                  0.005025    0.000000    0.000000    0.000000
# nerb                  0.000000    0.000000    0.000000    0.000000
# pgbv                  0.050251    0.058140    0.049123    0.030189
# rced                  0.316583    0.360465    0.382456    0.181132
# ujti                  0.208543    0.230233    0.266667    0.118868
# yjzv                  0.000000    0.000000    0.000000    0.003774
# yqyf                  0.005025    0.009302    0.003509    0.000000
# ysa7                  0.000000    0.000000    0.003509    0.022642
# ze6y                  0.005025    0.002326    0.007018    0.001887
# Total                 1.000000    1.000000    1.000000    1.000000
#
#                     2018-11-09  2018-11-10     ...      2018-11-21  \
# digital_service_id                             ...
# 2bpx                  0.005469    0.002860     ...        0.003375
# 39zx                  0.003646    0.000000     ...        0.000000
# 3tnn                  0.007293    0.018112     ...        0.178853
# 8onm                  0.007293    0.009533     ...        0.003375
# 8vlz                  0.577940    0.611058     ...        0.403825
# 96h9                  0.002735    0.000953     ...        0.000000
# bof3                  0.000000    0.000000     ...        0.003375
# c2jf                  0.004558    0.000953     ...        0.002250
# ch21                  0.000000    0.000000     ...        0.000000
# fx60                  0.004558    0.002860     ...        0.000000
# g58b                  0.000000    0.000000     ...        0.000000
# gg38                  0.000000    0.000000     ...        0.003375
# ghik                  0.001823    0.011439     ...        0.000000
# h43v                  0.000000    0.000000     ...        0.000000
# iwfn                  0.000000    0.000000     ...        0.001125
# j732                  0.000000    0.000000     ...        0.000000
# kcyg                  0.000000    0.000000     ...        0.000000
# l68b                  0.186873    0.171592     ...        0.134983
# l83h                  0.000912    0.000000     ...        0.047244
# lsff                  0.000000    0.000000     ...        0.019123
# lx6f                  0.000000    0.000000     ...        0.000000
# nerb                  0.000000    0.000000     ...        0.003375
# pgbv                  0.014585    0.019066     ...        0.016873
# rced                  0.107566    0.083889     ...        0.103487
# ujti                  0.061076    0.059104     ...        0.073116
# yjzv                  0.000000    0.000000     ...        0.001125
# yqyf                  0.004558    0.001907     ...        0.000000
# ysa7                  0.007293    0.005720     ...        0.000000
# ze6y                  0.001823    0.000953     ...        0.001125
# Total                 1.000000    1.000000     ...        1.000000
#
#                     2018-11-22  2018-11-23  2018-11-24  2018-11-25  \
# digital_service_id
# 2bpx                  0.001274    0.000000    0.014344    0.003503
# 39zx                  0.001274    0.000000    0.000000    0.000000
# 3tnn                  0.180892    0.102662    0.054303    0.057793
# 8onm                  0.002548    0.000000    0.002049    0.001751
# 8vlz                  0.391083    0.366920    0.564549    0.350263
# 96h9                  0.000000    0.000000    0.000000    0.000000
# bof3                  0.001274    0.001901    0.004098    0.001751
# c2jf                  0.003822    0.000000    0.001025    0.000000
# ch21                  0.000000    0.000000    0.000000    0.000000
# fx60                  0.003822    0.001901    0.004098    0.003503
# g58b                  0.000000    0.000000    0.000000    0.001751
# gg38                  0.001274    0.001901    0.001025    0.003503
# ghik                  0.001274    0.000000    0.001025    0.007005
# h43v                  0.002548    0.000000    0.000000    0.000000
# iwfn                  0.003822    0.000000    0.000000    0.001751
# j732                  0.000000    0.000000    0.000000    0.000000
# kcyg                  0.000000    0.000000    0.000000    0.000000
# l68b                  0.124841    0.205323    0.148566    0.225919
# l83h                  0.040764    0.053232    0.030738    0.085814
# lsff                  0.022930    0.000000    0.004098    0.021016
# lx6f                  0.000000    0.000000    0.000000    0.000000
# nerb                  0.000000    0.005703    0.000000    0.001751
# pgbv                  0.019108    0.036122    0.013320    0.021016
# rced                  0.091720    0.115970    0.091189    0.077058
# ujti                  0.104459    0.104563    0.065574    0.127846
# yjzv                  0.000000    0.000000    0.000000    0.000000
# yqyf                  0.000000    0.000000    0.000000    0.000000
# ysa7                  0.000000    0.000000    0.000000    0.000000
# ze6y                  0.001274    0.003802    0.000000    0.007005
# Total                 1.000000    1.000000    1.000000    1.000000
#
#                     2018-11-26  2018-11-27  2018-11-28  2018-11-29  2018-11-30
# digital_service_id
# 2bpx                  0.003067    0.001199    0.002740    0.001623      0.0000
# 39zx                  0.000000    0.000000    0.000000    0.000000      0.0000
# 3tnn                  0.049080    0.022782    0.027397    0.021104      0.0256
# 8onm                  0.000000    0.000000    0.000000    0.003247      0.0000
# 8vlz                  0.217791    0.425659    0.493151    0.498377      0.4816
# 96h9                  0.000000    0.000000    0.000000    0.000000      0.0000
# bof3                  0.000000    0.000000    0.000000    0.001623      0.0000
# c2jf                  0.000000    0.001199    0.002740    0.001623      0.0000
# ch21                  0.000000    0.000000    0.000000    0.000000      0.0000
# fx60                  0.009202    0.003597    0.002740    0.004870      0.0048
# g58b                  0.000000    0.000000    0.002740    0.000000      0.0000
# gg38                  0.003067    0.000000    0.004110    0.000000      0.0016
# ghik                  0.000000    0.000000    0.001370    0.001623      0.0000
# h43v                  0.000000    0.000000    0.000000    0.000000      0.0000
# iwfn                  0.003067    0.001199    0.000000    0.000000      0.0016
# j732                  0.000000    0.000000    0.000000    0.000000      0.0000
# kcyg                  0.000000    0.000000    0.000000    0.000000      0.0000
# l68b                  0.319018    0.128297    0.124658    0.163961      0.1600
# l83h                  0.098160    0.081535    0.097260    0.060065      0.1008
# lsff                  0.033742    0.009592    0.015068    0.021104      0.0176
# lx6f                  0.000000    0.000000    0.000000    0.000000      0.0000
# nerb                  0.003067    0.000000    0.000000    0.000000      0.0000
# pgbv                  0.049080    0.021583    0.017808    0.014610      0.0208
# rced                  0.104294    0.229017    0.120548    0.142857      0.1344
# ujti                  0.104294    0.070743    0.083562    0.063312      0.0496
# yjzv                  0.003067    0.001199    0.001370    0.000000      0.0016
# yqyf                  0.000000    0.000000    0.000000    0.000000      0.0000
# ysa7                  0.000000    0.000000    0.000000    0.000000      0.0000
# ze6y                  0.000000    0.002398    0.002740    0.000000      0.0000
# Total                 1.000000    1.000000    1.000000    1.000000      1.0000
#
# [30 rows x 30 columns]

# %%
all_devs = list_of_all_devs()
display(all_devs)
# Out:
#    digital_service_id            digital_service_name      business_unit  \
# 0                 kik                             kik          Ecosystem
# 1                p365                            p365          Ecosystem
# 2                swel                          Swelly          Ecosystem
# 3                tapa                        Tapatalk          Ecosystem
# 4                 kit                           Kinit         Standalone
# 5                tipc                          Tippic         Standalone
# 6                anon                       anonymous         Blockchain
# 7                g58b                         Kinetik  Developer Program
# 8                ujti                      Blastchat   Developer Program
# 9                yqyf           Find - Find travelers  Developer Program
# 10               ysa7                         beseech  Developer Program
# 11               lsff                          pop.in  Developer Program
# 12               ze6y              GoChallengeMe.club  Developer Program
# 13               h43v                    Coin Fantasy  Developer Program
# 14               rced                       KinTipBot  Developer Program
# 15               c2jf                         Reveald  Developer Program
# 16               fx60                         KIN VPN  Developer Program
# 17               8vlz                          Nearby  Developer Program
# 18               2bpx                        ThisThat  Developer Program
# 19               o1uo                           AddMe  Developer Program
# 20               yjzv                  Photo Mail Joy  Developer Program
# 21               3skw                          Caddle  Developer Program
# 22               54s3                    Hipster Bait  Developer Program
# 23               8k7q                  People's Press  Developer Program
# 24               a4jj                       WorkersAI  Developer Program
# 25               fpn3                   Draft Fantasy  Developer Program
# 26               ooxb                          remood  Developer Program
# 27               j732                         TestApp  Developer Program
# 28               ghik                        Kinguist  Developer Program
# 29               39zx  Syngli (com.syngli.androidapp)  Developer Program
# 30               iwfn                     Trivia Clan  Developer Program
# 31               8onm                           Kimeo  Developer Program
# 32               l83h                            Rave  Developer Program
# 33               7spn                    Step & Spend  Developer Program
# 34               nerb                       Klicktion  Developer Program
# 35               pgbv                       Pause For  Developer Program
# 36               kcyg                         Wicrypt  Developer Program
# 37               gg38             Rock Paper Scissors  Developer Program
# 38               m7dh                 RealityChainARC  Developer Program
# 39               96h9                           Visit  Developer Program
# 40               lx6f                        KinQuest  Developer Program
# 41               l68b                            Vent  Developer Program
# 42               ch21                      Matchmaker  Developer Program
# 43               3tnn                   ChatSwapDitch  Developer Program
# 44               bof3                          Panion  Developer Program
#
#                                     app_wallet_sender  \
# 0   GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 1   GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 2   GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 3   GDNJRI53DAO63JXQE2COPUDE3B3B6V5GGIIGE5QE4VZQZ5...
# 4   GDNM52OBYPX7TAOTFRPEED4DSOE6C7HSWFHCB5G45J2KDN...
# 5   GDY7PQHJFDKCZT63SXWXZKSWEZQ5OPBBWKJXNC7J7PWQIN...
# 6
# 7   GBYDL6PYATMA2JJKPI5BCV3YHDXF6XKSKAGJDU6Z4BVGZG...
# 8   GDNIRYKQCBO2W5NWA5J44ELKWJK7RWCRHVZB73A6XCRXMH...
# 9   GA7DR3H67JRSVYWCHL347NHJD2N2VIYK5KSU7X5NLABUNL...
# 10  GDXOHZT23TLQYB6WU7KA223EBRSDSUUW4DLQTR3TRZZUVZ...
# 11  GAKLAP65BMMWR55ZAJL4Q3SNCYH5AV473RMKF3ZNB2TURP...
# 12  GAAXXQ4ZG3WJ6F56LUZOIISAOXVGRULIMWQXG5HUDEUARU...
# 13  GAAIPW6R5EI7XBTDKDIHL3FDDNMVVDU4FW77TMSNNYK6GW...
# 14  GBY5PZFDZ6Y25S6YRRZ3CXOAIUWOZ3ADONFY2OYCA7GPQC...
# 15  GAWO64FLYRFMVQWCPE3CDYPMD3XJQV32AYI5HKPWZXDYDV...
# 16  GBY4L2F24VYN7ARISTVAGCQHCUTGPEWELMIMGJRMYMBBZ4...
# 17  GD3CJ4ROLGUTOC6MB26J3LZKN2ETZFMNU5ED3CXSREJB74...
# 18  GAAOCLQF3GF5S7JFKMKR2VXNVEV7IOCAQN7GIVQKWZORSG...
# 19  GBARJQSBHGAFWH3V3F3DY256ORC6CBQKYDDNQNZVJWCKBS...
# 20  GDTW6N2I3FGVWPMEL5FDFVK2EVWAC33ZOURIXTAQHCK5QS...
# 21  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 22  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 23  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 24  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 25  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 26  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 27  GDUBWR6ZLYHS6R6LO6DTOXNCRKPXODAC5DJB54H6PP62PM...
# 28  GCKVWVY6NB4W7I3BHUBAALPJKT6G36AR7O6BR3UPUWQZ5R...
# 29  GDULZIOODOF2TGVBSROLSZNBXDQMTVZKPTYZDDS3X357SY...
# 30  GDYPVKOA7OKOR2NNLJ77JDZJIRF5GI4OYYWJUX4XFZO4YK...
# 31  GBVTN6TIRXSKGUWLQVMPD75NX3AHYZECEJQ47ZN5XYPEOS...
# 32  GC2QIF2T7LZLYRGJ7JATB4EHT3MSKVN4ZOWL34REX723H4...
# 33  GDVA6AK6YUB45IPDT2YMR2EM4BSQUTJN4EIRYMZTTOJX4W...
# 34  GCHI2KN7X4AIS6RJPKNJZ7JEOIMO6BE4MZG5YUO4J2RSY3...
# 35  GDKH62PRA4QS3WRZHHFI2IS5IPFLTNQLMBK2FZOALE52DD...
# 36  GART3IWNQPRA6FW7ME5UP7W2CHT6LVCF54SE3BPERUS33S...
# 37  GCUPYQB3OTR5GIRU35XQGM3FMGGT47U52D6NKAU3EI2YZ2...
# 38  GBHVFGKB7IF5EZ4EWRXPDDHEVLTUJ663LRD23SKIWUAVRY...
# 39  GA3CW5PWFUHVNCRAADHO7KLXXWVBH7WVQXM5DFR7SEW3AT...
# 40  GCIXUJM6Q2XZTBF6Z3RJZKM6ZCXJBZYSZPUDPSHEJYEAY5...
# 41  GCI7NAZCQ6ETQGC2MMQKG6KZPZKV52DVCLQG23EOSSIQLR...
# 42  GAP37E3NRAHS2FB2KCH36LHEYOYCHVITGUK4TP43GZZLZX...
# 43  GBWBWHCBZIVCKP335KAG7MVV2ABMUYBR4XXDZX4KRTOMX5...
# 44  GAFDMWRKQMYUUL33J5PXK6BAED4BRGGOI4YSVKDPIKGXEY...
#
#                                  app_wallet_recipient  \
# 0   GCSMRVRSWROT5BYFPPGZEB6CJBPSRX6A4XW3HG7YBXN6B7...
# 1   GBOXPDOLQUNDLWTKYFLQG4AL57VVGFQUHM3SKB73EX5VN5...
# 2   GCTCD2PQF2SNLGFXTGEWQAQBN5R7THDXNGDAPPBAZ5L7VQ...
# 3   GDNZE5UPSCXYX37KDLR4T5YTR2UC5UHRYQIXE64QFSPNDJ...
# 4   GDNM52OBYPX7TAOTFRPEED4DSOE6C7HSWFHCB5G45J2KDN...
# 5   GDY7PQHJFDKCZT63SXWXZKSWEZQ5OPBBWKJXNC7J7PWQIN...
# 6
# 7   GA7HAPJH5AYUOAX5SB3TFL7TDCPRFCV7WNYIZK356LTCW6...
# 8   GA7U47SQCT274KX566PGE6XCOX4JRJFRAX6KT4BEHCJXKS...
# 9   GABTGSHEX62MZVQFJQWLKG63JSE6AMKGDPKZCM3AR7BDLF...
# 10  GADDN2H2OR2OZDZVS2NELGRY277DLSH7NLR3TTM2UQJ2VT...
# 11  GAE2V6GHNPY7TGUJUM7ANQBTLNG6N6YACGMOLPAYHM2JBP...
# 12  GAU53IKVGZCJOSZ5X7M7WW3KFXFLIMC3N7JQ26KJGQDNDE...
# 13  GAXGQ24THCN4P4G5O6Z6GJAYBHWUHURXMWJ5IA34D345B2...
# 14  GB4X45LZUCONWRBI3FR6N3AKUMR7J7YP7BGHPMTPVUXFZV...
# 15  GB57SWUOGRFVI2GTO5CD7FEPH7B6OPFIM2OGUNAUIJJYR5...
# 16  GBB343EQYGGJDVH342OEOOOH5DIW6C4G6T2D4KQDQ7PP6G...
# 17  GBK5HIGM7WYC7M6GYXE6OH7PTGFQNF5A35EHXLGQUWKU6G...
# 18  GBLOE7GZACNODWZF3SHSUCF77NUKXIOR7PXINTEXRTMYN6...
# 19  GBMZODC7BSXMNJTMF3JBEFB7VVM7AQCMQ5M2G4CWCHJGKC...
# 20  GBPXSDT3JIRRJZINQKHFJNBI3A5QMUS227K5KV4XG4PJRI...
# 21  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 22  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 23  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 24  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 25  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 26  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 27  GBUZFMZXZ6S2Y6HP5IIMTCESJJYJW32GFPN7XAVMRNE2OY...
# 28  GBVLLOPJMHRXH6GNPLYNL32PAL2FERZ7R7HUG6ER6TTYUV...
# 29  GBVO6HCRW6DIN4PA2X3NV67DJNOGRQAODXRTJQLZN6O6TE...
# 30  GBZ5S4ON3MNKXQ6RDZT3QFXNW46VRUQ7OPLMJ2PGJMDTTB...
# 31  GCBE5372NIV2DXTGXEXIJC74LMRA66OMGCLSRNSMQSCQ6S...
# 32  GCI3GVQJPSQNDJ7C6TFGEP6GTFSV2AQMFDUNUSWCJU45NH...
# 33  GCNU5SMZ5IHYBDWBNO6WX7RIETP3ML3PX7U63IRFIAEAZ7...
# 34  GCQ7Q2G5HMFNXZY7DMGUVFYIYFP5XLFJUL6ZO77SYQ6LJ3...
# 35  GD33O265ADR5J54YFG3ULMJWFAXRDPYF2D4I6DBD5ZV6YU...
# 36  GD3SDSMD5J6RC3B32F2F3TJYKFKVPOW2ZQL7KBXSQ5MX6N...
# 37  GD5APQUCJ3MU4J5V6L463R4BTHLCEAFG3XSVJ7IT5C3AXY...
# 38  GDCKCLXJIHTGZVCTE2LVNHTXCR5DBURACRI3C3NDWIDFNI...
# 39  GDDQTOIIVDRWS7RP4G43OO5UBG3XL3ZKYBPKSMJSA72TEC...
# 40  GDF5YWFJD3SWPPZPKTHIP6PM3YMRMYJTYTRGGVPW2J5HDJ...
# 41  GDJE5TH7NRJ7WAPM6FGQK4LGXTNB24JLH22PR5ZGUQBFFF...
# 42  GDMEJNWJ36JDVEDQQSMH7YB2MSVDGJCUGGWLCAXBH4OWSD...
# 43  GDSF5MARKJC2ZHFIEA72ARJMVUZRGYEGWTJFEDK2SOCXHM...
# 44  GDYDF26ZLMVGS4H7OH2AH6GI7SRVPSVA6PX6VT7DM2O2II...
#
#                                   app_wallet_sender_2  \
# 0
# 1
# 2
# 3
# 4   GC2KHQYTJ5W3642VGH6NMG7T7EJU2HTFDWVUQIQDE7J2PP...
# 5   GCDOBCS55PGWYER4A6TVRBLWUB6MXXC7JAV5JC3L2KY5ML...
# 6
# 7   GCKY6KRI6VPGTDLUCHHBM6PYQC3MT42J4O654AFLTIP37T...
# 8   GDGSEZP4NHBJCNUNOHNKD5RG7IEG3XJ26SPCO6TINZX6JS...
# 9   GDGVVFQDIDRHEE2RSV4E7ENXMJYVAIVWCQFSPCU7IMTJAQ...
# 10  GDLFBNMWB47HB3ODN2ELPLA5FRBDH6GP4RGAUPSF2XW364...
# 11  GADV5QPPTX7SJZLWHIELGIY44OVOFM3QVOCNEJ7CC5BB2E...
# 12  GAMQKRMIBUXM3Z2IXDKGCKDD6JAVJDG7L4LEPPJBUEY67J...
# 13  GCQDOT6UW76Z5JG5BZOHTSBWRHBBJRHTYTQUD7CEYG2237...
# 14  GCPJODUGBZ5B2WEX7QE4AMDSNTMW2C5X7WKG5H47KPF3IH...
# 15  GBBVM3IYH72NXLLLGOUD5MTPZ6XO4IJWLHTMU7MOQXZCXK...
# 16  GBIULDCTTW5LMNU6O3C6E6XBM467T2HVQWIGZUX3JTIOJ4...
# 17  GDCIL6JBVKU5MNZ6RI5ARDMLE5X36SO5G7BRZMU4VDHNFF...
# 18  GCKKMUR52OAIKKEENDN6BNYPIZGUAOUXLHALNWHPPG432B...
# 19  GC3Y3Y7DJ3J6PGNHI5KBUO7AXZXDTKUUYA6K3FVHDOFCEG...
# 20  GDUE7LQ27BBY4XRT7WZSZXS7Z5DYJCPPQ7VS4JEJ6UYUML...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  GCBU4CWDL4UTEFHN6ZYBXEHSPUP4Z7HL2GYKOT3TAAJ6TG...
# 28  GBDILZMDTRUVGKBNQPIRGBRESZJOJTYIOMZAPIO5KG62CP...
# 29  GBYFZHPN45DBGO3TKHQYMHEIRC2TDOKWFKNX2WVKZVK2NR...
# 30  GAT55APEP7Z5F5PKUYZFQP7DZHYUETSUO3E5HRSQCNN4VS...
# 31  GCHR5FH2Q56QZ4EAMY76EC4LYMRPU3ZNX6QKHRMUAFVGZE...
# 32  GAOZ3EZKG3WDUQL4DYPMQDM6Y7R3AAZ2AYMAXPA72CRTKT...
# 33  GBUC2SG2BZAA6B6WZTR6LJ374Q4OQQ36E4EWDRQYGXNZRZ...
# 34  GBQ2JYLYWCJONMOJLPWTQPGKQW3LJFALTOUMIKEDL2XU2V...
# 35  GANQDRSPRCSJA5M7DCM3J7NU37W3Q7SEHF65RPHULIHRBN...
# 36  GBNE2G2KX6JQL4OWS3SY7U3ZU2JVRW74QNLAU246YYXN4U...
# 37  GD4ENSM45YPC7WEZOT4PCMDWQ3ZHM7EHGVG2PZYEP75LHM...
# 38  GA7KXFT4I7KVLBWCRAQK2ZQQYOMSAVR3VMYX3VYT5OC3QB...
# 39  GCTFYOT7NDUQ6NZRNG4SAYBFU2FJKX274VNRHTS27W6MGJ...
# 40  GCRRWDSUSTFOISRRJLQEA6AGLKNO4W2JDCJZOW6NLJESF5...
# 41  GAJQMAYWFR7ZAOQDJYXDSZT5SY7UD47SXR6MB7OW5KVGG3...
# 42  GBRPA66YGBYJHXC4632SOT7AFAMPBJBG6WN7PNLHROO742...
# 43  GB56XEMW6FVB2Y6U2HZVKDPWGCRYQHKS5P55OA64O62FPM...
# 44  GAYYCGZ73JJNQEZSUJ2CKTD4QPSZNDP6O34KSXGFVCVVIM...
#
#                                app_wallet_recipient_2
# 0
# 1
# 2
# 3
# 4   GC2KHQYTJ5W3642VGH6NMG7T7EJU2HTFDWVUQIQDE7J2PP...
# 5   GCDOBCS55PGWYER4A6TVRBLWUB6MXXC7JAV5JC3L2KY5ML...
# 6
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None

# %%
all_devs[all_devs['digital_service_id']=='lx6f']['digital_service_name'].iloc[0]
# Out:
# 'KinQuest'
